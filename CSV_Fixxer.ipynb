# %% [markdown]
# Bibliotheken

# %%
from datetime import datetime, timedelta

# %%
df = pd.read_csv("retail_store_inventory.csv")
df.head()
# Out:
#          Date Store ID Product ID     Category Region  Inventory Level  \
# 0  2022-01-01     S001      P0001    Groceries  North              231
# 1  2022-01-01     S001      P0002         Toys  South              204
# 2  2022-01-01     S001      P0003         Toys   West              102
# 3  2022-01-01     S001      P0004         Toys  North              469
# 4  2022-01-01     S001      P0005  Electronics   East              166
#
#    Units Sold  Units Ordered  Demand Forecast  Price  Discount  \
# 0         127             55           135.47  33.50        20
# 1         150             66           144.04  63.01        20
# 2          65             51            74.02  27.99        10
# 3          61            164            62.18  32.72        10
# 4          14            135             9.26  73.64         0
#
#   Weather Condition  Holiday/Promotion  Competitor Pricing Seasonality
# 0             Rainy                  0               29.69      Autumn
# ...

# %% [markdown]
# Bestimmte Spalten löschen

# %%
df = df.drop(columns=["Demand Forecast"])

# %% [markdown]
# Datentyp von Date zu datetime umwandeln

# %%
df["Date"] = pd.to_datetime(df["Date"])
df = df.sort_values("Date")
df.head()
# Out:
#          Date Store ID Product ID     Category Region  Inventory Level  \
# 0  2022-01-01     S001      P0001    Groceries  North              231
# 72 2022-01-01     S004      P0013    Furniture   East              191
# 71 2022-01-01     S004      P0012  Electronics  North              349
# 70 2022-01-01     S004      P0011  Electronics   West              205
# 69 2022-01-01     S004      P0010    Groceries   East              447
#
#     Units Sold  Units Ordered  Price  Discount Weather Condition  \
# 0          127             55  33.50        20             Rainy
# 72          56             65  61.81         0             Sunny
# 71           9            165  14.25         5             Rainy
# 70          46             27  54.84         0             Sunny
# 69         104             96  33.48        15            Cloudy
#
#     Holiday/Promotion  Competitor Pricing Seasonality
# 0                   0               29.69      Autumn
# ...

# %%
df.to_csv("inventory_clean.csv", index=False)
